# %%
#import sys
import logging
#import os
#import xml.etree.ElementTree as ET
from src.environment import Environment
from src.runner import Runner

# %% [markdown]
# # Running the Solow Model
# First, the model needs to be initialized.

# %%
environment_directory = "environments/"
identifier = "test_all_methods"
log_directory = "log/"

# %% [markdown]
# Then, after a log folder is created, if it doesn't exist, the logger will be initialized. The log files will contain information about how the simulation went.

# %%
if not os.path.exists('log'):
    os.makedirs('log')

# %%
logging.basicConfig(format='%(asctime)s %(message)s', datefmt='%m/%d/%Y %H:%M:%S',
                    filename=log_directory + identifier + ".log", level=logging.INFO)
logging.info('START logging for run: %s',  environment_directory + identifier + ".xml")

# %% [markdown]
# Before initializing the model, let's inspect the parameters that are used to initialize it.

# %%
#tree = ET.parse('environments/test_all_methods.xml')
tree = ET.parse('environments/solow_parameters.xml')
root = tree.getroot()

# %%
# all item attributes
print('All parameters: ')
for elem in root:
    print(elem.attrib)
# Out:
# All parameters:
# {'name': 'num_sweeps', 'type': 'static', 'value': '30'}
# {'name': 'num_simulations', 'type': 'static', 'value': '1'}
# {'name': 'num_banks', 'type': 'static', 'value': '1'}
# {'name': 'num_firms', 'type': 'static', 'value': '1'}
# {'name': 'num_households', 'type': 'static', 'value': '1'}
# {'name': 'bank_directory', 'type': 'static', 'value': 'agents/banks/'}
# {'name': 'firm_directory', 'type': 'static', 'value': 'agents/firms/'}
# {'name': 'household_directory', 'type': 'static', 'value': 'agents/households'}
# {'name': 'measurement_config', 'type': 'static', 'value': 'measurements/test_output.xml'}

# %% [markdown]
# First, the environment will be initialized. It contains the model parameters and variables. The environment also contains a list of agents. In the Solow model, the environment contains one bank, one firm, and one household. Finally, it also contains initialized transactions for these agents

# %%
environment = Environment(environment_directory, identifier)

# %% [markdown]
# Next up, the runner object is created. As the name suggests, the runner object handles the running of the model. But that is not all, it also initializes the updater.

# %%
runner = Runner(environment)

# %% [markdown]
# Now you can actually run the model. Since the agent-based model is simulated using Monte Carlo methods. This means that the model will be run multiple times (num_simulations). For every simulation run, the environment and runner will be (re-)initialized. Then, the runner will run the Solow model. During the run, the runner will write data about capital to a csv file specified within the Measurement class and print out all the transactions happening and the books of firm and household at the end of each sweep.

# %%
for i in range(int(environment.num_simulations)):
    logging.info('  STARTED with run %s',  str(i))
    environment.initialize(environment_directory,  identifier)
    runner.initialize(environment)
    
    runner.do_run(environment)
    logging.info('  DONE')
# Out:
# measurements/test_output.xml
# household_test_config_ids sold 11.11382779811627d units of labour at a price 10.82116636037412f to firm_test_config_ids at time 0d.
# firm_test_config_ids sold 9.015874770237993d units of goods at a price 10.0f to household_test_config_ids at time 0d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='60.10583180158663'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='60.10583180158663'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='60.10583180158663'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='60.10583180158663'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 10.82383056253983d units of labour at a price 17.92952146184676f to firm_test_config_ids at time 1d.
# firm_test_config_ids sold 15.250316050322246d units of goods at a price 10.0f to household_test_config_ids at time 1d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='101.66877366881496'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='101.66877366881496'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='101.66877366881496'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='101.66877366881496'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 10.569890841005556d units of labour at a price 26.337570907591246f to firm_test_config_ids at time 2d.
# firm_test_config_ids sold 22.803241390757883d units of goods at a price 10.0f to household_test_config_ids at time 2d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='152.02160927171923'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='152.02160927171923'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='152.02160927171923'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='152.02160927171923'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 10.353595035449617d units of labour at a price 35.41307716616489f to firm_test_config_ids at time 3d.
# firm_test_config_ids sold 31.120456152559093d units of goods at a price 10.0f to household_test_config_ids at time 3d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='207.46970768372734'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='207.46970768372734'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='207.46970768372734'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='207.46970768372734'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 10.172627713004085d units of labour at a price 44.571663253651934f to firm_test_config_ids at time 4d.
# firm_test_config_ids sold 39.65283867075077d units of goods at a price 10.0f to household_test_config_ids at time 4d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='264.35225780500514'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='264.35225780500514'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='264.35225780500514'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='264.35225780500514'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 10.022982707548753d units of labour at a price 53.36100369800063f to firm_test_config_ids at time 5d.
# firm_test_config_ids sold 47.95132050765063d units of goods at a price 10.0f to household_test_config_ids at time 5d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='319.6754700510042'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='319.6754700510042'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='319.6754700510042'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='319.6754700510042'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.900200624379718d units of labour at a price 61.4807959892546f to firm_test_config_ids at time 6d.
# firm_test_config_ids sold 55.700861093471076d units of goods at a price 10.0f to household_test_config_ids at time 6d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='371.33907395647384'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='371.33907395647384'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='371.33907395647384'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='371.33907395647384'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.799989949731193d units of labour at a price 68.76623920705485f to firm_test_config_ids at time 7d.
# firm_test_config_ids sold 62.71485162398536d units of goods at a price 10.0f to household_test_config_ids at time 7d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='418.09901082656904'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='418.09901082656904'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='418.09901082656904'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='418.09901082656904'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.718497921443772d units of labour at a price 75.15705525619965f to firm_test_config_ids at time 8d.
# firm_test_config_ids sold 68.91076176694682d units of goods at a price 10.0f to household_test_config_ids at time 8d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='459.405078446312'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='459.405078446312'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='459.405078446312'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='459.405078446312'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.652396111802679d units of labour at a price 80.66520072399874f to firm_test_config_ids at time 9d.
# firm_test_config_ids sold 74.2810528963452d units of goods at a price 10.0f to household_test_config_ids at time 9d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='495.20701930896803'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='495.20701930896803'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='495.20701930896803'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='495.20701930896803'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.598874581592884d units of labour at a price 85.34739935181173f to firm_test_config_ids at time 10d.
# firm_test_config_ids sold 78.86676009312785d units of goods at a price 10.0f to household_test_config_ids at time 10d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='525.7784006208524'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='525.7784006208524'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='525.7784006208524'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='525.7784006208524'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.555595365659814d units of labour at a price 89.28433179582983f to firm_test_config_ids at time 11d.
# firm_test_config_ids sold 82.73660086530701d units of goods at a price 10.0f to household_test_config_ids at time 11d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='551.5773391020468'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='551.5773391020468'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='551.5773391020468'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='551.5773391020468'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.520631632235654d units of labour at a price 92.56615346230559f to firm_test_config_ids at time 12d.
# firm_test_config_ids sold 85.97193526977921d units of goods at a price 10.0f to household_test_config_ids at time 12d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='573.1462351318612'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='573.1462351318612'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='573.1462351318612'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='573.1462351318612'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.492405537688818d units of labour at a price 95.28316438836431f to firm_test_config_ids at time 13d.
# firm_test_config_ids sold 88.65676034522907d units of goods at a price 10.0f to household_test_config_ids at time 13d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='591.0450689681938'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='591.0450689681938'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='591.0450689681938'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='591.0450689681938'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.46963072149825d units of labour at a price 97.5203044000653f to firm_test_config_ids at time 14d.
# firm_test_config_ids sold 90.87158036909479d units of goods at a price 10.0f to household_test_config_ids at time 14d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='605.8105357939652'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='605.8105357939652'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='605.8105357939652'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='605.8105357939652'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.451261719768d units of labour at a price 99.35430334106117f to firm_test_config_ids at time 15d.
# firm_test_config_ids sold 92.69004357933326d units of goods at a price 10.0f to household_test_config_ids at time 15d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='617.9336238622218'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='617.9336238622218'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='617.9336238622218'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='617.9336238622218'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.436450746938435d units of labour at a price 100.85256883738501f to firm_test_config_ids at time 16d.
# firm_test_config_ids sold 94.1774353439054d units of goods at a price 10.0f to household_test_config_ids at time 16d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='627.8495689593694'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
# ...
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='670.2653589296978'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.2653589296978'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.375115815987513d units of labour at a price 107.24643210681998f to firm_test_config_ids at time 45d.
# firm_test_config_ids sold 100.5427848469546d units of goods at a price 10.0f to household_test_config_ids at time 45d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='670.2852323130307'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.2852323130307'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='670.2852323130307'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.2852323130307'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.375093278992122d units of labour at a price 107.2488384704237f to firm_test_config_ids at time 46d.
# firm_test_config_ids sold 100.5451858222087d units of goods at a price 10.0f to household_test_config_ids at time 46d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='670.3012388147247'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.3012388147247'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='670.3012388147247'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.3012388147247'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.375075127422965d units of labour at a price 107.25077660318382f to firm_test_config_ids at time 47d.
# firm_test_config_ids sold 100.54711961664181d units of goods at a price 10.0f to household_test_config_ids at time 47d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='670.3141307776121'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.3141307776121'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='670.3141307776121'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.3141307776121'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.375060508049705d units of labour at a price 107.25233760594591f to firm_test_config_ids at time 48d.
# firm_test_config_ids sold 100.54867712778778d units of goods at a price 10.0f to household_test_config_ids at time 48d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='670.3245141852522'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.3245141852522'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='670.3245141852522'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.3245141852522'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
# measurements/test_output.xml
# household_test_config_ids sold 9.375048733536307d units of labour at a price 107.25359486066729f to firm_test_config_ids at time 49d.
# firm_test_config_ids sold 100.54993157105802d units of goods at a price 10.0f to household_test_config_ids at time 49d.
#   <agent identifier='household_test_config_id'>
#     <type value='household'>
#     <parameter type='agent' name='labour' value='24.0'></parameter>
#     <parameter type='agent' name='propensity_to_save' value='0.4'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#         <transaction type='deposits'>
#             <property type='from' value='household_test_config_id'></property>
#             <property type='to' value='bank_test_config_id'></property>
#             <property type='amount' value='670.3328771403869'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.3328771403869'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>
#
#   <agent identifier='firm_test_config_id'>
#     <type value='firm''>
#     <parameter type='agent' name='productivity' value='1.25'></parameter>
#     <parameter type='agent' name='active' value='0'></parameter>
#     <parameter type='agent' name='total_factor_productivity' value='1.8'></parameter>
#     <parameter type='agent' name='labour_elasticity' value='0.3'></parameter>
#     <parameter type='agent' name='capital_elasticity' value='0.7'></parameter>
#         <transaction type='loans'>
#             <property type='from' value='bank_test_config_id'></property>
#             <property type='to' value='firm_test_config_id'></property>
#             <property type='amount' value='670.3328771403869'></property>
#             <property type='interest' value='0.0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#         <transaction type='capital'>
#             <property type='from' value='firm_test_config_id'></property>
#             <property type='to' value='household_test_config_id'></property>
#             <property type='amount' value='670.3328771403869'></property>
#             <property type='interest' value='0'></property>
#             <property type='maturity' value='0'></property>
#             <property type='time_of_default' value='-1'></property>
#         </transaction>
#   </agent>

# %% [markdown]
# So, now the model has been run. But what did it actually do? Head to the Analyse_Solow notebook to find out.
